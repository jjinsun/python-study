# %% [markdown]
# ### 11. while문
# - 조건이 True인 동안 코드를 반복하는 반복문
# - 조건이 False가 되면 반복을 멈춤
#     - 반복 횟수가 정해지지 않았을 때 사용

# %%
# while문 기본 문법
# 조건 : 참/거짓을 구분할 수 있는 문장 → Ture, False를 반환하는 문장이 와야 함


while 조건:
    # 반복할 코드

# %%
# 무한루프
# 사용시 주의해야 함
# 반드시 종료조건이 있어야 함!
while True:
    print("반복중")

# %%
# 예제1

light = "green"

while light == "green":
    print("계속 가세요!")
    light = input("산호등의 신호를 입력해주세요(green/yellow/red)")
print("중지❌")
# Out:
# 계속 가세요!
# 계속 가세요!
# 계속 가세요!
# 중지❌

# %%
import time

# 예제2 : 별도의 반복 변수를 정의
# ⚠️반복 변수를 갱신하지 않을시 무한루프에 빠지게 됨
i = 0

while i < 5:
    print(i, "반복")
    i += 1
    time.sleep(1)
print("반복 종료")
# Out:
# 0 반복
# 1 반복
# 2 반복
# 3 반복
# 4 반복
# 반복 종료

# %%
# 실습1.
# 문제1.
secret_code = ""

while secret_code != "codingonre3":
    print("비밀 코드를 입력하세요:")
    secret_code = input("다시입력하세요😩")
    print(secret_code) # 생략가능
print("입장이 허용되었습니다😊")
# Out:
# 비밀 코드를 입력하세요:
# 비밀 코드를 입력하세요:
# 비밀 코드를 입력하세요:
# 입장이 허용되었습니다😊

# %%
# 문제2-1.
answer = 77
num = 0 # 사용자 입력 받을 변수
time = 0 # 실행횟수를 저장할 변수

# 사용자 입력과 정답이 같지 않을 때 반복
while num != answer:
    num = int(input("1~100사이의 수를 입력해주세요"))
    time += 1

    if num > answer:
        print(f"정답이 {num}보다는 작아요.")

    elif num < answer:
        print(f"정답이 {num}보다 커요.")

print(f"{time}번 만에 정답을 맞췄습니다.")
# Out:
# 정답이 50보다 커요.
# 정답이 70보다 커요.
# 정답이 78보다는 작아요.
# 정답이 76보다 커요.
# 5번 만에 정답을 맞췄습니다.

# %%
import random

# 문제2-2.
answer = random.randint(1,100)
num = 0 # 사용자 입력 받을 변수
time = 0 # 실행횟수를 저장할 변수

# 사용자 입력과 정답이 같지 않을 때 반복
while num != answer:
    num = int(input("1~100사이의 수를 입력해주세요"))
    time += 1

    if num > answer:
        print(f"정답이 {num}보다는 작아요.")

    elif num < answer:
        print(f"정답이 {num}보다 커요.")

print(f"{time}번 만에 정답을 맞췄습니다.")
# Out:
# 정답이 50보다는 작아요.
# 정답이 20보다는 작아요.
# 정답이 20보다는 작아요.
# 정답이 40보다는 작아요.
# 정답이 50보다는 작아요.
# 정답이 10보다는 작아요.
# 정답이 1보다 커요.
# 정답이 2보다 커요.
# 정답이 3보다 커요.
# 정답이 4보다 커요.
# 정답이 4보다 커요.
# 정답이 5보다 커요.
# 13번 만에 정답을 맞췄습니다.

# %%
# 루프 제어문
runnung = True
while runnung :
    if 조건1:
        runnung = False
    if 조건2:
        runnung = False

# break
while True:
    if 조건:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 runnung = True
#       3 while runnung :
# ----> 4     if 조건1:
#       5         runnung = False
#       6     if 조건2:
#
# NameError: name '조건1' is not defined

# %%
# 예제1
i = 0

while True:
    print(i, "실행")
    my_select = input("메뉴를 골라주세요:")

    if my_select == "종료":
        break

    if i < 5:
        break

    i += 1
print("반복문 종료")
# Out:
# 0 실행
# 반복문 종료

# %%
# 예제1-1 <bresk를 만나자 마자 종료>
i = 0

while True:
    i += 1
    if i > 5:
        break

    print(i, "실행")
print("반복문 종료")
# Out:
# 1 실행
# 2 실행
# 3 실행
# 4 실행
# 5 실행
# 반복문 종료

# %%
# 예제1-2 <실행이 다시 돌아와서 종료>
i = 0

while i < 6:
    i += 1

    print(i, "실행")
print("반복문 종료")

# 일반적으로 while의 조건에 따라 while문을 종료시키면 실핼블록이 끝까지 된 후 종료되지만
# break로 종료를 시키면, 이후 실핼블록의 코드는 무시되고 바로 반볻문을 탈출함
# Out:
# 1 실행
# 2 실행
# 3 실행
# 4 실행
# 5 실행
# 6 실행
# 반복문 종료

# %%
# continue
i = 0
while i < 5:
    i += 1
    if i % 2== 0:
        continue
    print(i)
print("반복 종료")
# Out:
# 1
# 3
# 5
# 반복 종료

# %%
# 실습2
# 문제1.
secret_code = "codingonre3"
user_input = ""

# 비밍코드와 사용자 입력이 같지 않을때 반복
while True:
     user_input = input("비밀 코드를 입력하세요:")

     if user_input == secret_code:
          print("입장 완료! 환영합니다.")
          break
     else:
          print("비밀 코드가 틀렸습니다. 다시 시도하시오")
# Out:
# 비밀 코드가 틀렸습니다. 다시 시도하시오
# 비밀 코드가 틀렸습니다. 다시 시도하시오
# 입장 완료! 환영합니다.

# %%
# 문제2.

cnt = 0
sum_age = 0

while cnt < 5:
    age = int(input("나이를 입력하세요: "))

    # 나이가 0이하 이거나(또는), 120초과이면 건너뜀
    if age <= 0 or  age > 120:
        continue

    cnt += 1
    sum_age += age

print(f"총 나이 합계는 {sum_age}, 평균은 {int(sum_age / cnt)}")
# Out:
# 총 나이 합계는 136, 평균은 27

# %%
# 중첩 while문
# 예제

dan = 2 
while dan <= 9:
    num = 1
    print(f"[ {dan}단 ]")

    while num <= 9:
        print(f"{dan} x {num} = {dan * num}")
        num += 1
        
    print()
    dan += 1
# Out:
# [ 2단 ]
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
#
# [ 3단 ]
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
#
# [ 4단 ]
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
#
# [ 5단 ]
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
#
# [ 6단 ]
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
#
# [ 7단 ]
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
#
# [ 8단 ]
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
#
# [ 9단 ]
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81

# %%
# 실습3
# 문제1
user_id = "wlsr5678"
user_pw = "Sun11"

while True:
    # 아이디 확인
    id_input = input("ID를 입력하세요.: ")

    # 아이디가 일치하지 않을 시
    if id_input != user_id:
        print("ID가 일치하지 않습니다.")
        continue

    while True:
        # 비밀번호 확인
        pw_input = input("비밀번호를 입력하세요.: ")

        # 비밀번호가 일치하지 않을 시
        if pw_input != user_pw:
            print("PW가 일치하지 않습니다.")
            continue

        print("로그인 성공✅")
        break

    break
# Out:
# ID가 일치하지 않습니다.
# ID가 일치하지 않습니다.
# PW가 일치하지 않습니다.
# PW가 일치하지 않습니다.
# PW가 일치하지 않습니다.
# 로그인 성공✅
