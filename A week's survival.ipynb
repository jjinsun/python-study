# %%
# All 아니오/ ⭐️최종체력: -30
# 초기 상태 설정
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
inventory = []

print(f"{player_name}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴")
print(f"초기 체력: {health}")
print("")

# 1일차 (월요일)
print("[월요일] 배고픈 아침입니다. 🥖 발견했습니다.")
eat_bread = input("🥖 먹겠습니까? (예/아니오): ")
if eat_bread == "예":
    health += 10
    inventory.append("🥖")
    print("🥖 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다... (체력 -10)")

print(f"현재 체력: {health}")
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

# 2일차 (화요일)
if health > 0:
    print("[화요일] ☠️🍄 널려 있습니다.")
    mushroom = input("☠️🍄 피해가겠습니까? (예/아니오): ")
    if mushroom == "예":
        print("현명한 선택입니다! (체력 변동 없음)")
    else:
        health -= 30
        print("☠️🍄 먹고 배탈이 났습니다... (체력 -30)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 3일차 (수요일)
if health > 0:
    print("[수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.")
    fish = input("🐟 낚시하겠습니까? (예/아니오): ")
    if fish == "예":
        Fire = input("🔥을 피우시겠습니까? (예/아니오): ")
        if Fire == "예":
            health += 15
            inventory.append("🐟+🔥")
            print("🔥 피워 따뜻하게 먹었습니다! (체력 +15)")
        else:
            health -= 50
            print("🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("")
    else:
        print("사냥🔫을 준비해야 합니다. (체력 변화 없음)")
        print(f"현재 체력: {health}")
        print("")

# 4일차 (목요일)
if health > 0:
    print("[목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.")
    item_1 = input("염소🐐와 싸우겠습니까?(예/아니오-도망): ")
    if item_1 == "예":
        health += 30
        inventory.append("🐐")
        print("염소고기🐐를 얻었습니다. (체력 +30)")
    else:
        health -= 20
        print("도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")
        
# 5일차 (금요일)
if health > 0:
    print("[금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.")
    shelter = input("집을🏕️ 짓겠습니까? (예/아니오): ")
    if shelter == "예":
        health += 25
        inventory.append("🏕️")
        print("집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)")
    else:
        health -= 20
        print("비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 6일차 (토요일)
if health > 0:
    print("[토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.")
    cave = input("동굴을🧭 탐험🗺️하겠습니까? (예/아니오): ")
    if cave == "예":
        health += 30
        inventory.append("회복물약🧪")
        print("동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)")
    else:
        print("동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 7일차 (일요일)
if health > 0:
    print("[일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!")
    raft = input("뗏목⛵️+🪵을 만들겠습니까? (예/아니오): ")
    if raft == "예":
        print("🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉")
        print(f"⭐️최종 체력: {health}")
        print(f"⭐️최종 소지품: {inventory}")
        print(f"⭐️축하합니다! {player_name}🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️")  
    else:
        health -= 50
        print("뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("기진맥진했지만, 여전히 희망을 잃지 않았습니다.🌞")
# Out:
# Kim님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴
# 초기 체력: 100
#
# [월요일] 배고픈 아침입니다. 🥖 발견했습니다.
# 🥖 먹고 힘이 납니다! (체력 +10)
# 현재 체력: 110
#
# [화요일] ☠️🍄 널려 있습니다.
# 현명한 선택입니다! (체력 변동 없음)
# 현재 체력: 110
#
# [수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.
# 🔥 피워 따뜻하게 먹었습니다! (체력 +15)
# 현재 체력: 125
#
# [목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.
# 염소고기🐐를 얻었습니다. (체력 +30)
# 현재 체력: 155
#
# [금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.
# 집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)
# 현재 체력: 180
#
# [토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.
# 동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)
# 현재 체력: 210
#
# [일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!
# 🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉
# ⭐️최종 체력: 210
# ⭐️최종 소지품: ['🥖', '🐟+🔥', '🐐', '🏕️', '회복물약🧪']
# ⭐️축하합니다! Kim🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️

# %% [markdown]
# ### 7/15/화 자습_파이썬 미니 프로젝트 ‘텍스트 게임’ 만들기
# # 일주일간의 던전 생존기(A week's survival)

# %%
# All 예/ ⭐️최종 체력: 210 ⭐️최종 소지품: ['🥖', '🐟+🔥', '🐐', '🏕️', '회복물약🧪']
# 초기 상태 설정
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
inventory = []

print(f"{player_name}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴")
print(f"초기 체력: {health}")
print("")

# 1일차 (월요일)
print("[월요일] 배고픈 아침입니다. 🥖 발견했습니다.")
eat_bread = input("🥖 먹겠습니까? (예/아니오): ")
if eat_bread == "예":
    health += 10
    inventory.append("🥖")
    print("🥖 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다... (체력 -10)")

print(f"현재 체력: {health}")
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

# 2일차 (화요일)
if health > 0:
    print("[화요일] ☠️🍄 널려 있습니다.")
    mushroom = input("☠️🍄 피해가겠습니까? (예/아니오): ")
    if mushroom == "예":
        print("현명한 선택입니다! (체력 변동 없음)")
    else:
        health -= 30
        print("☠️🍄 먹고 배탈이 났습니다... (체력 -30)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 3일차 (수요일)
if health > 0:
    print("[수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.")
    fish = input("🐟 낚시하겠습니까? (예/아니오): ")
    if fish == "예":
        Fire = input("🔥을 피우시겠습니까? (예/아니오): ")
        if Fire == "예":
            health += 15
            inventory.append("🐟+🔥")
            print("🔥 피워 따뜻하게 먹었습니다! (체력 +15)")
        else:
            health -= 50
            print("🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("")
    else:
        print("사냥🔫을 준비해야 합니다. (체력 변화 없음)")
        print(f"현재 체력: {health}")
        print("")

# 4일차 (목요일)
if health > 0:
    print("[목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.")
    item_1 = input("염소🐐와 싸우겠습니까?(예/아니오-도망): ")
    if item_1 == "예":
        health += 30
        inventory.append("🐐")
        print("염소고기🐐를 얻었습니다. (체력 +30)")
    else:
        health -= 20
        print("도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")
        
# 5일차 (금요일)
if health > 0:
    print("[금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.")
    shelter = input("집을🏕️ 짓겠습니까? (예/아니오): ")
    if shelter == "예":
        health += 25
        inventory.append("🏕️")
        print("집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)")
    else:
        health -= 20
        print("비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 6일차 (토요일)
if health > 0:
    print("[토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.")
    cave = input("동굴을🧭 탐험🗺️하겠습니까? (예/아니오): ")
    if cave == "예":
        health += 30
        inventory.append("회복물약🧪")
        print("동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)")
    else:
        print("동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 7일차 (일요일)
if health > 0:
    print("[일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!")
    raft = input("뗏목⛵️+🪵을 만들겠습니까? (예/아니오): ")
    if raft == "예":
        print("🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉")
        print(f"⭐️최종 체력: {health}")
        print(f"⭐️최종 소지품: {inventory}")
        print(f"⭐️축하합니다! {player_name}🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️")
    else:
        health -= 50
        print("뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("기진맥진했지만, 여전히 희망을 잃지 않았습니다.🌞")
# Out:
# Jin님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴
# 초기 체력: 100
#
# [월요일] 배고픈 아침입니다. 🥖 발견했습니다.
# 🥖 먹고 힘이 납니다! (체력 +10)
# 현재 체력: 110
#
# [화요일] ☠️🍄 널려 있습니다.
# 현명한 선택입니다! (체력 변동 없음)
# 현재 체력: 110
#
# [수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.
# 🔥 피워 따뜻하게 먹었습니다! (체력 +15)
# 현재 체력: 125
#
# [목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.
# 염소고기🐐를 얻었습니다. (체력 +30)
# 현재 체력: 155
#
# [금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.
# 집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)
# 현재 체력: 180
#
# [토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.
# 동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)
# 현재 체력: 210
#
# [일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!
# 🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉
# ⭐️최종 체력: 210
# ⭐️최종 소지품: ['🥖', '🐟+🔥', '🐐', '🏕️', '회복물약🧪']
# ⭐️축하합니다! Jin🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️

# %%
# All 아니오(단,🐟예, 🔥아니오)/ ⭐️최종체력: -10
# All 아니오
# 초기 상태 설정
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
inventory = []

print(f"{player_name}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴")
print(f"초기 체력: {health}")
print("")

# 1일차 (월요일)
print("[월요일] 배고픈 아침입니다. 🥖 발견했습니다.")
eat_bread = input("🥖 먹겠습니까? (예/아니오): ")
if eat_bread == "예":
    health += 10
    inventory.append("🥖")
    print("🥖 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다... (체력 -10)")

print(f"현재 체력: {health}")
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

# 2일차 (화요일)
if health > 0:
    print("[화요일] ☠️🍄 널려 있습니다.")
    mushroom = input("☠️🍄 피해가겠습니까? (예/아니오): ")
    if mushroom == "예":
        print("현명한 선택입니다! (체력 변동 없음)")
    else:
        health -= 30
        print("☠️🍄 먹고 배탈이 났습니다... (체력 -30)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 3일차 (수요일)
if health > 0:
    print("[수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.")
    fish = input("🐟 낚시하겠습니까? (예/아니오): ")
    if fish == "예":
        Fire = input("🔥을 피우시겠습니까? (예/아니오): ")
        if Fire == "예":
            health += 15
            inventory.append("🐟+🔥")
            print("🔥 피워 따뜻하게 먹었습니다! (체력 +15)")
        else:
            health -= 50
            print("🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("")
    else:
        print("사냥🔫을 준비해야 합니다. (체력 변화 없음)")
        print(f"현재 체력: {health}")
        print("")

# 4일차 (목요일)
if health > 0:
    print("[목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.")
    item_1 = input("염소🐐와 싸우겠습니까?(예/아니오-도망): ")
    if item_1 == "예":
        health += 30
        inventory.append("🐐")
        print("염소고기🐐를 얻었습니다. (체력 +30)")
    else:
        health -= 20
        print("도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")
        
# 5일차 (금요일)
if health > 0:
    print("[금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.")
    shelter = input("집을🏕️ 짓겠습니까? (예/아니오): ")
    if shelter == "예":
        health += 25
        inventory.append("🏕️")
        print("집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)")
    else:
        health -= 20
        print("비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 6일차 (토요일)
if health > 0:
    print("[토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.")
    cave = input("동굴을🧭 탐험🗺️하겠습니까? (예/아니오): ")
    if cave == "예":
        health += 30
        inventory.append("회복물약🧪")
        print("동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)")
    else:
        print("동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 7일차 (일요일)
if health > 0:
    print("[일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!")
    raft = input("뗏목⛵️+🪵을 만들겠습니까? (예/아니오): ")
    if raft == "예":
        print("🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉")
        print(f"⭐️최종 체력: {health}")
        print(f"⭐️최종 소지품: {inventory}")
        print(f"⭐️축하합니다! {player_name}🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️")
    else:
        health -= 50
        print("뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("기진맥진했지만, 여전히 희망을 잃지 않았습니다.🌞")
# Out:
# Sun님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴
# 초기 체력: 100
#
# [월요일] 배고픈 아침입니다. 🥖 발견했습니다.
# 아침을 거르고 기운이 빠집니다... (체력 -10)
# 현재 체력: 90
#
# [화요일] ☠️🍄 널려 있습니다.
# ☠️🍄 먹고 배탈이 났습니다... (체력 -30)
# 현재 체력: 60
#
# [수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.
# 🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)
# 현재 체력: 10
#
# [목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.
# 도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)
# 현재 체력: -10
# 😢 체력이 바닥나 쓰러졌습니다. 게임 오버

# %%
# All 예(단,🐟예, 🔥아니오)/ ⭐️최종 체력: 145 ⭐️최종 소지품: ['🥖', '🐐', '🏕️', '회복물약🧪']
# All 아니오
# 초기 상태 설정
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
inventory = []

print(f"{player_name}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴")
print(f"초기 체력: {health}")
print("")

# 1일차 (월요일)
print("[월요일] 배고픈 아침입니다. 🥖 발견했습니다.")
eat_bread = input("🥖 먹겠습니까? (예/아니오): ")
if eat_bread == "예":
    health += 10
    inventory.append("🥖")
    print("🥖 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다... (체력 -10)")

print(f"현재 체력: {health}")
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

# 2일차 (화요일)
if health > 0:
    print("[화요일] ☠️🍄 널려 있습니다.")
    mushroom = input("☠️🍄 피해가겠습니까? (예/아니오): ")
    if mushroom == "예":
        print("현명한 선택입니다! (체력 변동 없음)")
    else:
        health -= 30
        print("☠️🍄 먹고 배탈이 났습니다... (체력 -30)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 3일차 (수요일)
if health > 0:
    print("[수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.")
    fish = input("🐟 낚시하겠습니까? (예/아니오): ")
    if fish == "예":
        Fire = input("🔥을 피우시겠습니까? (예/아니오): ")
        if Fire == "예":
            health += 15
            inventory.append("🐟+🔥")
            print("🔥 피워 따뜻하게 먹었습니다! (체력 +15)")
        else:
            health -= 50
            print("🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("")
    else:
        print("사냥🔫을 준비해야 합니다. (체력 변화 없음)")
        print(f"현재 체력: {health}")
        print("")

# 4일차 (목요일)
if health > 0:
    print("[목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.")
    item_1 = input("염소🐐와 싸우겠습니까?(예/아니오-도망): ")
    if item_1 == "예":
        health += 30
        inventory.append("🐐")
        print("염소고기🐐를 얻었습니다. (체력 +30)")
    else:
        health -= 20
        print("도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")
        
# 5일차 (금요일)
if health > 0:
    print("[금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.")
    shelter = input("집을🏕️ 짓겠습니까? (예/아니오): ")
    if shelter == "예":
        health += 25
        inventory.append("🏕️")
        print("집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)")
    else:
        health -= 20
        print("비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 6일차 (토요일)
if health > 0:
    print("[토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.")
    cave = input("동굴을🧭 탐험🗺️하겠습니까? (예/아니오): ")
    if cave == "예":
        health += 30
        inventory.append("회복물약🧪")
        print("동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)")
    else:
        print("동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 7일차 (일요일)
if health > 0:
    print("[일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!")
    raft = input("뗏목⛵️+🪵을 만들겠습니까? (예/아니오): ")
    if raft == "예":
        print("🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉")
        print(f"⭐️최종 체력: {health}")
        print(f"⭐️최종 소지품: {inventory}")
        print(f"⭐️축하합니다! {player_name}🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️")
    else:
        health -= 50
        print("뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("기진맥진했지만, 여전히 희망을 잃지 않았습니다.🌞")
# Out:
# KKim님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴
# 초기 체력: 100
#
# [월요일] 배고픈 아침입니다. 🥖 발견했습니다.
# 🥖 먹고 힘이 납니다! (체력 +10)
# 현재 체력: 110
#
# [화요일] ☠️🍄 널려 있습니다.
# 현명한 선택입니다! (체력 변동 없음)
# 현재 체력: 110
#
# [수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.
# 🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)
# 현재 체력: 60
#
# [목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.
# 염소고기🐐를 얻었습니다. (체력 +30)
# 현재 체력: 90
#
# [금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.
# 집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)
# 현재 체력: 115
#
# [토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.
# 동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)
# 현재 체력: 145
#
# [일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!
# 🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉
# ⭐️최종 체력: 145
# ⭐️최종 소지품: ['🥖', '🐐', '🏕️', '회복물약🧪']
# ⭐️축하합니다! KKim🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️

# %%
# All 아니오(단,🐟예, 🔥예)/ ⭐️최종체력: -15
# All 아니오
# 초기 상태 설정
player_name = input("당신의 이름은 무엇입니까? ")
health = 100
inventory = []

print(f"{player_name}님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴")
print(f"초기 체력: {health}")
print("")

# 1일차 (월요일)
print("[월요일] 배고픈 아침입니다. 🥖 발견했습니다.")
eat_bread = input("🥖 먹겠습니까? (예/아니오): ")
if eat_bread == "예":
    health += 10
    inventory.append("🥖")
    print("🥖 먹고 힘이 납니다! (체력 +10)")
else:
    health -= 10
    print("아침을 거르고 기운이 빠집니다... (체력 -10)")

print(f"현재 체력: {health}")
if health <= 0:
    print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
else:
    print("")

# 2일차 (화요일)
if health > 0:
    print("[화요일] ☠️🍄 널려 있습니다.")
    mushroom = input("☠️🍄 피해가겠습니까? (예/아니오): ")
    if mushroom == "예":
        print("현명한 선택입니다! (체력 변동 없음)")
    else:
        health -= 30
        print("☠️🍄 먹고 배탈이 났습니다... (체력 -30)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 3일차 (수요일)
if health > 0:
    print("[수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.")
    fish = input("🐟 낚시하겠습니까? (예/아니오): ")
    if fish == "예":
        Fire = input("🔥을 피우시겠습니까? (예/아니오): ")
        if Fire == "예":
            health += 15
            inventory.append("🐟+🔥")
            print("🔥 피워 따뜻하게 먹었습니다! (체력 +15)")
        else:
            health -= 50
            print("🔥 피우지 못해 추위와 체력 저하로 쓰러졌습니다. (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("")
    else:
        print("사냥🔫을 준비해야 합니다. (체력 변화 없음)")
        print(f"현재 체력: {health}")
        print("")

# 4일차 (목요일)
if health > 0:
    print("[목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.")
    item_1 = input("염소🐐와 싸우겠습니까?(예/아니오-도망): ")
    if item_1 == "예":
        health += 30
        inventory.append("🐐")
        print("염소고기🐐를 얻었습니다. (체력 +30)")
    else:
        health -= 20
        print("도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)")

    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")
        
# 5일차 (금요일)
if health > 0:
    print("[금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.")
    shelter = input("집을🏕️ 짓겠습니까? (예/아니오): ")
    if shelter == "예":
        health += 25
        inventory.append("🏕️")
        print("집을🏕️ 지어 비를🌧️🌪️ 피했습니다! 푹 쉬어서 체력이 회복됩니다.😎 (체력 +25)")
    else:
        health -= 20
        print("비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 6일차 (토요일)
if health > 0:
    print("[토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.")
    cave = input("동굴을🧭 탐험🗺️하겠습니까? (예/아니오): ")
    if cave == "예":
        health += 30
        inventory.append("회복물약🧪")
        print("동굴🧭에서 회복물약🧪을 발견해 체력이 크게 회복됩니다! (체력 +30)")
    else:
        print("동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)")
    print(f"현재 체력: {health}")
    if health <= 0:
        print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
    else:
        print("")

# 7일차 (일요일)
if health > 0:
    print("[일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!")
    raft = input("뗏목⛵️+🪵을 만들겠습니까? (예/아니오): ")
    if raft == "예":
        print("🌊 뗏목⛵️+🪵을 완성해서 강을🏞️ 따라 무사히 탈출했습니다! 🎉")
        print(f"⭐️최종 체력: {health}")
        print(f"⭐️최종 소지품: {inventory}")
        print(f"⭐️축하합니다! {player_name}🥇님은 7일간 던전에서 생존에 성공했습니다!🎖️")
    else:
        health -= 50
        print("뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)")
        print(f"현재 체력: {health}")
        if health <= 0:
            print("😢 체력이 바닥나 쓰러졌습니다. 게임 오버")
        else:
            print("기진맥진했지만, 여전히 희망을 잃지 않았습니다.🌞")
# Out:
# JJin님, 일주일간 던전 생존기에 오신 걸 환영합니다!🌴
# 초기 체력: 100
#
# [월요일] 배고픈 아침입니다. 🥖 발견했습니다.
# 아침을 거르고 기운이 빠집니다... (체력 -10)
# 현재 체력: 90
#
# [화요일] ☠️🍄 널려 있습니다.
# ☠️🍄 먹고 배탈이 났습니다... (체력 -30)
# 현재 체력: 60
#
# [수요일] 🐟가 나타났습니다. 물고기를 낚시할 수 있습니다.
# 🔥 피워 따뜻하게 먹었습니다! (체력 +15)
# 현재 체력: 75
#
# [목요일] 염소🐐를 만났습니다! 싸우거나 도망칠 수 있습니다.
# 도망으로..굶주림💀과 체력 저하로 쓰러졌습니다. (체력 -20)
# 현재 체력: 55
#
# [금요일] 갑자기 폭우🌧️🌪️가 내리기 시작합니다. 임시로 집을🏕️ 지을 수 있습니다.
# 비를🌧️🌪️ 맞으며 밤을 보내 체력이 깎였습니다... (체력 -20)
# 현재 체력: 35
#
# [토요일] 신비로운 동굴을🧭 발견했습니다. 탐험🗺️을 할 수 있습니다.
# 동굴🧭 입구에서 쉬었습니다. (체력 변화 없음)
# 현재 체력: 35
#
# [일요일] 드디어 강가🏞️에 도착했습니다. 뗏목⛵️+🪵을 만들어 던전을 나갈 수 있습니다!
# 뗏목⛵️+🪵을 만들지 못해 강을🏞️ 건너지 못했습니다... (체력 -50)
# 현재 체력: -15
# 😢 체력이 바닥나 쓰러졌습니다. 게임 오버

# %% [markdown]
# ### Github 주소: https://github.com/jjinsun/python-study.git
# # 프로그래머스: 코딩테스트
