# %% [markdown]
# 2025출제
# 굴필매직
# 50억
#
# 안전관리자 증원 · 교체임명을 명할 수 있 는 경우 4가지를 쓰시오.
# 1해당사업장의연간재해율이같은업종 의평균재해율의2배이상인경우
# 2중대재해가연간2건이상발생한경우
# 3관리자가질병이나그밖의사유로3개월 이상 직무를 수행할 수 없게 된 경우
# 4화학적인자로인한직업성질병자가연 간3명이상발생한경우
#
# 산업안전보건법령상, 고용노동부장관이 산업재해 예방을 위하여 종합적인 개선조치를 할 필요가 있다고 인정되는 사업장의 사업주에게 "안전보건개선계획"을 수립하여 시행할 것을 명할 수 있는 3가지를 작성하시오.
# 1.산업재해율이 같은 업종 평균 산업재해율의 2배 이상인 사업장
# 2 사업주가 안전 • 보건조치의무를 이행하지 아니하여 중대재해가 발생한 사업장
# 3 직업성 질병자가 연간 2명 이상 발생한 사업장
# 4 유해인자의 노출기준을 초과한 사업장
#
#
#
# 📚🌞물질안전보건자료(MSDS)내용을 근로자에게 교육해야하는경우2가지= 물질안전자료 교육시기2가지
# 채용시
# 작업내용변경시
# 최초 노무 제공 시
# 유해성,위험성 정보가 변경된 경우
# 물질안전보건자료 대상물질을 제조,사용,운반,저장하는 작업에 근로자를 배치하게 된 경우
# 새로운 물질안전보건자료 대상물질이 도입된 경우
# 유해
#
# 📚🌞물질안전보건자료(MSDS)교육내용5가지-대건취적응물
# 대상화학물질 명칭
# 건강 유해성,물리적 위험성
# 취급상의 주의사항
# 적절한 보호구
# 응급조치요령과 사고시대처방법
# 물질안전보건자표,경고표지를 이해하는방법
#
# 📚🌞물질안전보건자료(MSDS)포함사항6가지-유응화누노안
# 유해성,위험성
# 응급조치요령
# 화재,폭발시 대처방법
# 누출 사고시 대처방법
# 노출방지 및 개인보호구
# 안전성, 반응성
#
# 📚🌞물질안전보건자료(MSDS)제외대상6가지-화폐비사농식
# 화장품, 폐기물, 비료, 시료, 농약, 식품 및 식품첨가물
#
# 🔥잠함 또는 우물통의 급격한 침하에 의한 위험을 방지하기 위해,준수해야 할 사항2가지
# 침하관계도에 따라 굴착방법 및 재하량등을 정할 것
# 바닥으로부터 천장 또는 보까지의 높이를 1.8m 이상으로 할 것
#
# 🔥잠함
# 산소 결핍 우려가 잇는 경우에는 [산소의농도]를 측정하는 [사람]을 지명하여 측정하도록 할 것
# 근로자가 안전하게 오르내리기 위한 설비를 설치할 것
# [굴착깊이]가 [20m]를 초과하는 경우에는 해당 작업장소와 외부와의 연락을 위한 [통신설비] 등을 설치할것
#
# 🔥부두,안벽 하역작업 시 사업주의 조치사항 3가지를 쓰시오
# 화물을 취급하는 작업 등에 사업주는 바닥으로부터의 높이가 [2m이상]되는 [하적단]과 인접 하적단 사이의 간격을 하적단의 밑부분을 기준으로 하여 [10cm]이상으로 하여야 한다.
# [작업장] 및 [통로]의 [위험한부분에는] 안전하게 작업할 수 있는 [조명]을 [유지]할 것.
# 부두 또는 안벽의 선을 따라 통로를 설치하는 경우에는 [폭을90cm이상]으로 할 것.
# 육상에서의 [통로] 밑 [작업장소]로서 [다리] 또는 [선거갑문]을 넘는 [보도]등의 위험한 부분에는 [안전난간] 또는 [울타리등]을 설치할 것
#
# ⭐️압력용기 등에 표시가 지워지지 않도록 각인 표시하여야 하는 사항
# [최고사용압력]
# [제조연월일]
# [제조회사명]
#
# ⭐️재해발생형태: 넘어짐
# 기인물: 기름
# 가해물: 선반
#
# ⭐️상부틀의 각 개구의 폭 또는 길이는 [16cm]미만으로 할 것
# 강도는 [지게차] [최대하중]의 2배(4톤이 넘으면 4톤으로 할 것)에 해당하는 [등분포정하중]에 견딜수 있도록 할 것
# 운전자가 앉아서 조작하거나 서서 조작하는 경우 한국표준산업에서 정하는 높이 기준의 이상이 되도록 할 것
# 좌식: 0.903m
# 입식: 1.905m
#
# 🌳반드시 파열판-반급운
# [반응폭주] 등 [급격한압력상승]의 우려가 있는 경우
# [급성독성물질]의 누출로 인한 주위의 [작업환경]을 오염시킬 우려가 있는 경우
# 운전중 안전밸브에 이상물질이 누적되어 안전밸브가 작동되지 아니 할 우려가 있는 경우
#
# 🌳안전밸브+파열판-정정배
# 정변위 압축기
# 정변위 펌프(토출구에 차단밸브가 설치된 경우에 한함)
# 배관(2개 이상의 밸브에 의하여 차단되어 대기온도에서 액체의 열팽창에 의하여 파열될 우려가 있는 것으로 한정.)
#
# 🔥사업주는 급성독성물질이 지속적으로 외부에 유출될 수 있는 화학설비 및 그 부속설비에 파열판과 안전밸브를 [직렬]로 설치하고, 그 사이에는 [압력지시계] 또는 [자동경고장치]를 설치하여야 한다.
# 사업주는 안전밸브등이 안전밸브등을 통하여 보호하려는 설비의 최고사용압력 이하에서 작동되도록 하여야 한다.
# 다만, 언전밸브등이 2개이상 설치된 경우에 1개는 최고사용압력의 [1.05배] 외부화재를 대비한 경우에는 [1.1배]이하에서 작동되도록 설치할 수 있다.
#
# ⭐️각 사업장의 안전관리자 최소 인원
# 식료품 제조업 : 600명:  2명
# 1차 금속제조업: 200명:  1명
# 플라스틱제품 제조업: 300명: 1명
# 건설현장: 총 공사금액 1000억 이상: 2명
#
# ⭐️다음 회사는 매년 회사의 안전및보건에관한 계획을 수립하여 이사회에 보고하고 [승인]을 받아야 한다.
# 상시근로자 [100명이상]을 사용하는 회사
# [건설산업기본법] 제23조에 따라 평가하여 공시된 시공능력의 순위 상위 [1000위이내]의 건설회사
#
# 🍄유해위험기계등이 안전인증기준에 적합한지 확인하기 위하여 [안전인증기관이심사하는심사의종류4가지]
# [예비심사] 7일
# [서면심사] 15일
# [기술능력] 및 [생신체계]심사 30일
# [제품심사] 30일(방호장치, 보호구는 60일)
#
# 🍄안전인증대상 기계, 설비
# 전리 배고프아서 롤케이크 사곤해
# 전단기 및 절곡기, 고소작업대, 프레스, 압력용기, 롤러기, 사출성형기,
# 리프트, 크레인, 곤돌라
#
# 🍄안정인증대상 방호장치
# [보일러 업력방출용 안전밸브]
# [압력용기 압력방출용 안전밸브]
# [압력용기 압력방출용 파열판]
# [프레스 및 전단기의 방호장치]
# [양중기용 과부하방지장치]
# [방폭구조 전기기계 기구 및 부품]
#
# 🍄안전인증 심사 중 형식별 제품심사: 60일
# 안전인증대상 보호구 5가지
# 안전화
# 안전대
# 안전장갑
# 방진마스크
# 방독마스크
# 송기마스크
# 전동식 호습 보호구
# 보호복
# 추락 및 감전위험방지용 안전모
#
# 🍄안전인증대상 제품이 표시해야 할 사항
# 제조자[명]
# 제조[년월]
# 제조[번호]
# [안전인증]번호
# [모델명]
#
# 2025 2회차 실기 필답형 출제
# 추락,비래,감전에 의한 위험을 방지할 수 있는 안전모의 성능시험 항목4가지
# 수전관 턱! 충격 난연성
# 내수성
# 내전압성
# 내관통성
# 턱끈 풀림
# 충격 흡수성
# 난연성
#
# ⭐️내전압성: AE, ABE종 안전모는 교류 🔥20kV에서 🔥1분간 절연파괴 없이 견뎌야 하고, 이때 누설되는 충전전류는 🔥10mA이어야 한다.
# 내관통성: AE, ABE종 안전모는 관통거리가 🔥9.5mm이하이고, AB종 안전모는 관통거리가 🔥11.1mm이하이어야 한다.
# 충격 흡수성: 최고전달충격력이 🔥4450 N 을초과해서는 안되며, 모체와 착장체의 기능이 상실되지 않아야 한다.
#
# ✅로봇의 특별안전보건교육
# 로안조이-기본원리,구조,작업방법
# 로봇의 기본원리 구조 및 작업방법에 관한사항
# 안전시설 및 안전기준에 관한사항
# 조작방법 및 작업순서에 관한사항
# 이상발생시 응급조치에 관한사항
#
# ✅로봇의 오조작 방지
# 로직이2-조작방법,순서
# 로봇의 조작방법 및 순서
# # 작업중의 매니퓰레이터의 속도
# 이상발견시 조치사항
# 2명이상의 근로자에게 작업을 시킬경우 신호방법
#
# ✅로봇의 작업시작전 점검사항
# 외매제
# 외부전선의 피복 및 외장의 손상여부
# # 매디풀레이터의 작동의 이상유무
# 제동장치 및 비상정지장치의 기능
#
# 건설용 리프트,곤돌라 특별안전보건교육
# 신호방법,기계기구달기체인,방호장치의 기능,기계기구의 특성 및 공동작업, 와이어등의 점검,사용,동작원리에 관한사항
#
# 🔥공정안전보고서 제출 대상 상업4가지
# 원유정제처리업
# 기타 석유정제물 재저리업
# 화약 및 불꽃제품 제조업
# 석유화학계 기타화학물질 제조업
# 합성수지 및 기타 플라스틱물질 제조업
#
# 2025 2회차 실기 필답형 출제
# 🔥공정안전보고서 포함사항4가지
# 공정 안전 자료
# 공정 위험성 평가서
# 안전 운전 계획
# 비상 조치 계획
#
# ⭐️비파괴검사의 실시기준
# 고속 회전체(회전축의 중량이 [1톤]을 초과하고, 원주속도가 초당 [120m] 이상인 것으로 한정한다.)
#
# ⭐️아세틸렌 안전기 설치
# 취관, 분기관, 발생기와 가스용기 사이
#
# ⭐️환경미화 업무 근로자 위생시설 4가지
# 휴게시설
# 세면,목욕시설
# 세탁시설
# 탈의시설
# 수면시설
#
# ⭐️차광보언경의 사용구분에 따른 종류 4가지
# 자외선용
# 적외선용
# 복합용
# 용접용
#
# ⭐️비,눈 비계의 작업 시작 전 점검사항4가지
# 손잡이의                       탈락상태
# 발판재료의   손상여부  및 부착  또는 걸림상태
# 연결재료의   연결철물  의 손상  또는 부식상태
# 기둥의 침하, 변형,변위   또는      흔들림상태
# 해당비계의    연결부   또는  접속부 풀림상테
# 로프의                         부착상태
# 매단장치의                      흔들림상태
#
# ⭐️재해원인 4M
# 맨       Man
# 메신스    Machine
# 미디아    Media
# 메네지먼트 Management
#
# ⭐️Ex d IIB T6
#
# 🔥산업재해 발생 건수 및 재해율 또는 그 순위 등을 공표할 수 있는 대상 사업장의 종류2가지
# [산업재해] 발생 사실을 [은폐한] 사업장
# [중대산업사고]가 발생한 사업장
#
# 🔥중대산업사고:[유해하거나] [위험한설비가] 있는경우 그 설비로부터,
# [위험물질누출],[화재],[폭발]등으로인하여 [사업장내의] 근로자에게 [즉시피해]를 주거나,
# [사업장] [인근지역에] 피해를 줄 수 있는 [사고]로서,[대통령령]으로 정하는 사고
#
# 🔥중대산업사고 예방 고용노동부장과에게 제출서류: [공정안전보고서]
#
# 🔥중대재해 해당사항3가지
# 사망자가 [1인] 이상 발생한 [재해]
# 3개월 이상 요양이 필요한 부상자가 동시에 2인 이상 발생한 재해
# 부상자 또는 직업성 질병자가 동시에 10인 이상 발생한 재해
#
# ⭐️유해물질의 취급 등으로 근로자에게 유해한 작업에 있어서 그 원인을 제거하기 위하여 조치해야할 사항3가지 = 작업 환경 개선 원칙 3가지-대격환
# [대치,격리,환기]
#
# ⭐️기계 설비의 방호 원리 3가지-위차덮위
# [위험제거],[차단],[덮어씌움],[위험의적응]
#
# ⭐️기계 방호장치의 분류 중 [위험장소에따른분류]에 해당하는 [격리식방호장치]의 종류 3가지-완덮안
# [완전차단형], [덮개형], [안전방책]
#
# ⭐️안전보건표지 경고표지의 종류 4가지
# 인화성물질 경고, 산화성물질 경고, 폭발성물질 경고, 급성독성물질 경고, 부식성물질 경고, 발암성·변이성·전신독성·생식독성·호흡기 과민성물질 경고,
# 방사성물질 경고, 고압전기 경고, 매달린 물체 경고, 낙하물 경고, 고온경고, 저온경고, 몸균형 상실 경고, 레이저광선 경고, 위험장소 경고
#
# ⭐️위험성 평가 실시순서
# [준파결실공기]
# 준비 파악 결과 실행 공유 기록
#
# ⭐️산업재해 통계적 분석방법
# 파레토도: 사고의 유형, 기인물 등 항목값이 큰 순서대로 정리하단.
# 특성요인도: 특성과 재해요인을 어골상으로 세분화하여 나타낸다.
# 크로스 분석: 2개 이상의 문제관계를 분석하여 사용한다.
# 관리도: 재해발생 건수의 대략적인 추이를 파악하여 사용한다.
#
# ⭐️화학설비 또는 그 배관의 밸브나 콕에 내구성이 있는 재료를 선정할 때 고려사항4가지
# 위험물질 등의 [종류]
# 위험물질 등의 [온도]
# 위험물질 등의 [농도]
# 개폐의   [빈도]
#
# ⭐️누전차단기
# 정격감도전류: 30mA 이하
# 작동시간: 0.03초(30ms) 이내
#
# ⭐️도급사업의 합동 안전보건점검을 하는 경우, 점검반의 구성하여야 하는 사람3명을 쓰시오.
# 도급인
# 관계수급인
# 도급인 및 관계수급인의 근로자 각 1명씩
#
# ⭐️공정위험분석(PHA) 주요목표를 달성하기 위한 4가지 특징 - 파국적,위기적,한계적,무시
# [시스템의]                     [모든주요한]             [사고]를 식별하고,   대략적인 [말]로 표현할 것
# [사고를]                       [유발하는]              [요인]을 식별할 것
# [사고가발생한다고가정한] [후],      [시스템에생기는]          [결과]를 식별하고,    [평가]할 것
# [식별된사고를] "파국적","위기적","한계적","무시"의                        [4가지범주]로 [분류]할 것
#
# ⭐️위험점의 종류 및 정의 - 협왕고프, 끼회직고연, 절회자밀
#     협착점: 왕복운동을 하는        동작부분과      운동이 없는      고정부분 사이에 형성되는 위험점(프레스)
#     끼임점: 회전운동을 하는        동작부분과      운동이 없는      고정부분이 함께 형성하는 위험점(연삭기)
#     절단점: 회전하는            운동부 자체 및      운동하는       기계부분       자체의 위험점(벨트,밀링기)
#     물림점: 회전하는        [2개의회전체에]       물려들어가는           위험점(톱날)
# 점선물림점: 회전하는         [부분의접선방향으로]    물려들어가는           위험점(롤러)
# 회전말림점: 회전하는         [물체에작업복등이]    말려들어가는           위험점(드릴)
#
# ⭐️관리감독자의 업무 4가지
# 해당 사업장의 산업보건의, 안전보건담당자, 안전관리자, 보건관리자에대한 지도조언의 협조
# 해당 작업장의 정리정돈 및 통로확보에 대한 확인감독
# 근로자의 작업복/보호구 및 방호장치의 점검과 그 착용/사용에 대한 교육/지도
# 기계.기구 또는 설비의 안전보건점검이상유무
#
# ⭐️산업재해조사표의 주요작성 항목 아닌것
# 목격자의 인적사항, 가해물, 치료 요양기관, 재해발생후 첫 출근일자,
# 보호자의 성명, 급여수준, 응급조치내역, 재해자 복귀일시
#
# ⭐️자율검사프로그램 인정 취소나 개선을 요구하는 경우4가지
# 자율검사프로그램을 거짓이나 그 밖의 부정한 방법으로 인정 받은 경우
# 자율검사프로그램을 인정받고도 검사를 하지 아니한 경우
# 인정받은 자율검사프로그램의 내용에 따라 검사를 하지 아니한 경우
# 자율검사안전자격을 갖춘자 또는 자율안전검사기관이 검사를 하지 아니한 경우
#
# ⭐️어디서: 사출성형부 플라스틱 용기 생산1팀 사출공정 사출성형기 2호기
# 누가: 재해자A와 동료작업자 1명
# 무엇을: 재해자 A가 사출성형기 2호기에서 플라스틱 용기를 꺼낸 후 금형을 점검
# 어떻게: 재해자가 점검중임을 모르던 동료근로자B가 사출성형기 조작스위치를 가동하여 금형사이에 재해자가 끼어 사망
#
# ✅사업주의 의무
# 이법과 이법에 따른 명령으로 정하는 산업재해예방을 위한 기준을 지킬것
# 근로자의 신체적 피로와 정신적 스트래스등을 줄일수 있는
# 쾌적한 작업환경을 조성하고 근로조건을 개선할 것
# 헤당 사업장의 안전보건에관한 정보를 제공할 것
#
# ✅근로자의 의무
# 이법과 이법에 따른 명령으로 정하는 기준등, 산업재해예방에 필요한 사항을 지킬것
# 사업주 또는 근로감독관, 공단등의 관계자가 실시하는 산업재해 방지에관한 조치에 따라야한다
#
# Fail safe(기계고장예방): 자동전격방지기, 누전차단기, 비상하강장치
# Fool poof(인간실수예방): 방호물, 덮개, LOTO, 권과방지장치
# 🔥정의
# 기계의 고장이 발생하더라도, 기계설비가 안전하게 작동
# 인간의 실수가 발생하더라도, 기계설비가 안전하게 작동
#
# Fail safe(페일세이프)를 기능면에서 3가지
# Fail active:    부품이 고장나면      기계는     경보음이 울리고, 짧은 시간 운전이 가능하다
# Fail passive:   부품이 고장나면      기계장치는  정지 상태로 옮겨간다
# Fail operation: 부품이 고장나더라도            다음 정기 점검까지 운전이 가능하다
#
# ✅연소의 3요소 및 소화방법
# 산소공급원: 질식소화
# 점화원: 냉각소화
# 가연성물질: 제거소화
#
# ✅인간기계 통합 시스템의 정보처리 기능 5가지
# 입력
# 감지
# 정보처리 및 의사결정
# 행동
# 출력
# 정보보관
#
# 🔥보일러의 이상 현상 중 캐리오버 현상원인4가지-보열보운
# 보일러의 운전압력을 너무 낮게 설정해 놓았을 때
# 열부하가 급격하게 변동해 증감될 때
# 보일러수가 과잉 농축되었을 때
# 운전중 수위조절이 원활하게 이뤄지지 못한 경우
# 기수분리기 등의 기계적 고장
#
# 🔥보일러의 폭발사고방지 유지관리 장치3가지
# 압력방출장치
# 압력제한 스위치
# 고저 수위조절장치
# 화염검출기
#
# 🔥하인리히의 재해예방 대책5단계 순서-안사분시시
# [안전조직], [사실의발견], [분석], [시정책선정], [시정책적용]
#
# 🔥목재가공용 둥근톱기계의 분할날 설치내용
# 분할날과 톱날 후면과의 간격은 [12mm] 이내일 것
# 분할날 두께는 톱 두께의 [1,1배] 이상이며 폭보다 작을 것
# 톱날 후면 날의 [2/3]이상을 덮어 설치 할 것
# 분할날 조임볼트는 [2개] 이상일 것
# 분할날 조임볼트는 [이완방지]조치가 되어있을것
# 재료는 KS D 3751(탄소공구강재)에서 정한 STC 5 (탄소공구강) 또는 이와 동등이상의 재료를 사용할 것
#
# ⭐️시스템 안전을 실행하기 위한 시스템 안전프로그램(SSPP)포함사항 4가지-조직,기준,해석,평가
# [안전조직],[안전기준],[안전해석],[안전성평가],계획의 개요,계약조건
#
# 소음 노출 기준: (4/8+ 2/4) *100= 100%
# 노출기준 초과여부 : 초과하지 않음
#
# 🔥공기압축기 점검사항
# 윤활유의 상태
# 회전체의 덮개 또는 울
# 압력방출장치의 기능
# 언로드 밸브의 기능
# 드레인 밸브의 조작 및 배수
# 공기저장 압력용기의 외관상태
#
# 🔥🔥근로불능상해 정도
# 영구 전  노동 불능상해: (신체장해등급 제 1 ~3급) [부상의결과]                [노동기능을]       [완전히]     [잃는]         부상정도
# 영구 일부 노동 불능상해: (신체장해등급 제4~ 14급) [부상의결과]  [신체부위의일부가]   [노동기능을]               [상실한]       부상정도
# 일시 전  노동 불능상해:                     [의사의진단에따라]   [일정기간]   [정규노동에]      [종사할수없는]         상해정도
# 일시 일부 노동 불능상해:                    [의사의진단에따라]            [정규근로에]         [종사할수없는]         상해정도
#
# ✅빨간색, 금지, [특정행위의지시] 및 사실의고지, N9.5
#
# 용어 서술
# 🔥UVCE(증기운폭발) :   인화성 가스가 대기 중에 존재하다가 점화원에 의해 폭발
# 🔥BLEVE(비등액체 팽창 증기폭발): 비점 이상의 온도에서, 액체상태로 들어있는 용기파열시 폭발
#
# 🔥비등액체 팽창 증기폭발(BLEVE)에 영향을 주는 인자3가지
# 저장탱크에 저장된 물질의 종류와 형태
# 저장탱크에 저장된 물질의 인화성 여부
# 저장용기의 재질
# 저장탱크 주위의 온도와 압력
#
# 🔥산업재해 조치순서
# 산업재해발생, 긴급처리, 재해조사, 원인강구, 대책수립, 대책실시계획, 실시, 평가
#
# ⭐️포버디-크키퍼
# [포크,버키,디퍼]등의 장치를 가장 낮은 위치 또는 지면에 내려 둘 것
# [원동기를정지시키고], [브레이크]를 [확실히거는]등 [차랑계기계]의 [갑작스러운이동을방지]
#
# ⭐️건설용 리프트, 곤돌라를 이용하는 작업에서 사업자가 근로자에게 실시해야 하는 특별안전보건교육 내용 4가지
# 신기방기 및 공와사동에 관한 사항
# 신호방법 및 공동작업에 관한사한
# 기계기구달기체인 및 와이어등의 점검에 관한사항
# 방호장치의 기능 및 사용에관한사항
# 기계기구의 특성  및 동작원리에관한사항
#
# 🐠유해위험방지계획서 제출/ 대상공사
# 터널건설등 공사
# 깊이가 [10m] 이상 굴착공사
# 최대지간 길이가[50m] 이상 교량건설등 공사
# 지상 높이가 [31m] 이상 건축물 또는 인공구조물
# 연면적 [3만제곱미터] 이상 건축물
#
# 🐠유해위험방지계획서 제출/ 기계,기구 및 [설비]경우3가지-화건가금
# [화학]설비
# [건조]설비
# [가스]집합 용접장치
# 금속이나 그 밖의 광물의 용해로
#
# 🐠유해위험방지계획서 제출/ 건축물 또는 [시설공사]의 종류4가지-가구마해기
# [가설]공사
# [구조]공사
# [마감]공사
# [해체]공사
# [기계설비]공사
#
# 🐠유해위험방지계획서 제출/ 기한, 첨부서류 2가지
# 해당 공사의 착공전날 까지
# 공사개요, 안전보건관리계획, [작업공사] 종류별 유해위험방지계획
#
# 🐠유해위험방지계획서 제출/ 설치,이전,구조변경 첨부서류3가지
# 건축물 [각층의] 평면도
# [기계설비]의 [개요]를 나타내는 서류
# [기계설비]의 [배치도면]
# 제조등의 작업방법의 개요
#
# 🔥🔥화학설비 또는 그 부속 설비의 용도를 변경하는 경우에 해당 설비를 점검내용3가지
# 그 설비,내부에 [폭발,화재]의 우려가 있는 물질이 있는지
# [안전밸브,긴급차단장치] 및 그 밖의 [방호장치] [기능의이상유무]
# [냉각장치], [가열장치], [교반장치], [압축장치], [계측장치] 및 [제어장치] [기능의이상유무]
#
# ⭐️가연성물질이 있는 장소에서 화재위험작업을 하는 경우에 화재예방을 위해서 사업주가 준수하여야 할 사항 3가지
# [작업준비] 및 [작업절차] 수립
# 작업장 내 위험물의 [사용,보관] 현황 파악
# 작업근로자에 대한 [화재예방] 및 [피난교육]등 비상조치
#
# ⭐️가설통로 설치 시 사업주의 준수사항
# 견고한 구조로 할 것
# 경사는 [30도] 이하일것(단, 계단을 설치하거나, 높이 2m미만의 가설통로로서 튼튼한 손잡이를 설치한 경우에는 그러하지 아니하다.)
# 경사가 [15도]를 초과하는 경우에는 미끄러지지 아니하는 구조로 할 것
#
# ⭐️타워크레인을 설치,해체하는 작업에서 사업자가 근로자에게 실시해야 하는 특별안전보건교튝의 내용- 붕설부신
# [붕설부신] 및 [재안특요] 에 관한사항
# 붕괴,추락             재해방지
# 설치,해체             안전작업방법
# 부재의 구조,재질        특성
# 신호방법              요령
#
# ⭐️중대산업사고 정의: 설비로부터의 위험물질 누출, 화재 및 폭발등으로 인한 사업장내의 근로자에게 즉시피해를 주거나, 사업장 인근지역에 피해를 줄 수 있는 사고
# 중대사고예방을 위해 작성하고 고용노동부장관에게 제출하여 심사를 받아야 하는 보고서 명칭: 공정안전보고서
#
# 2025 2회차 실기 필답형 출제
# ⭐️기계,기구에 설치하여애 할 방호장치
# 원심기    :    회전체 날 접촉예방장치
# 예초기    :         날 접촉예방장치
# 금속절단기 :         날 접촉예방장치
# 공기압축기 :     압력방출방치
# 지게차    :   헤드가드, 백레스트, 전조등, 후미등, 안전밸트
#
# ⭐️허가대상물질 작업장, 석면취급/해체 작업장, 금지대상의 취급 실험실등 표지 하단에 작성해야 하는 내용2가지 관계자외 출입금지
# 보호구/보호복 착용
# 흡연 및 음식물 섭취 금지
#
# 🛜터널강아치 지보공
# 조주연띠-터
# ✅조립간격는 조립도에 따를것
# ✅주재가 아치작용을 충분히 할 수 있도록 쐐기를 박는등 필요한 조치를 할것
# ✅연결볼트 및 띠장등을 사용하여 [주재상호간]을 튼튼하게 연결할 것
# ✅터널등의 출입구 부분에는 받침대를 설치할 것
#
# 🔥감전방지용 누전차단기를 설치하는 전기기계,기구3가지-대물철임
# [대지전압이150V초과]하는 이동형 또는 휴대형 전기기계,기구
# 물 등[도전성이높은액체가있는]습윤장소에서 사용하는 저압용 전기기계,기구
# [철판,철골위등도전성이]높은 장소에서 사용하는 이동형 또는 휴대형 전기기계,기구
# [임시배선의전로가설치되는장소에서] 사용하는 이동형 또는 휴대형 전기기계,기구
#
# 🔥사업주가 누전에 의한 감전의 위험을 방지하기 위하여 [코드와플러그]를 접속하여 접지를 해야하는 전기기계,기구-냉물
# 냉장고,세탁기,컴퓨터 등 고정형 전기기계,기구
# 물 또는 도전성이 높은 곳에서 사용하는 전기기계,기구,[비접지형콘센트]
#
# 🔥전기기계기구를 설치할 때, 고려사항3가지
# 전기기계,기구의 충분한 [전기적 용량] 및 [기계적 강도]
# [습기,분진] 등 [사용장소]의 [주위환경]
# [전기적,기계적] [방호수단]의 [적정성]
#
# ⭐️[300명이상]
# 농업, 어업, [소프트웨어개발및공급업], 컴퓨터 프로그래밍, 시스템 통합 및 관리업, 정보서비스업, 금융,보험업, 임대업(부동산제외), 전문,과학,기술서비스업(연구개발업제외), 사업지원서비스업, 사회복지서비
#
# ⭐️[그외100명이상]
# 자동차제조업
#
# ⭐️고용노동부장관은 사업주가 필요한 안전조치 또는 보건조치를 이행하지 아니하여 중대재해가 발생한 사업장에 안전보건진단을 받아 [안전보건개선계획]을 수립하여 시행할 것을 명할 수 있다.
# 사업주는 수립,시행 명령을 받은 날부터 [60일이내]에 관할 지방고용노동관서의 장에게 해당 계획서를 제출해야 한다.
#
# ⭐️설치이전하거나 구조변경, 유해위험방지계획서 제출할 시 서류3가지
# 건축물 각 층의 평면도
# 기계,설비의 개요를 나타내는 서류
# 기계,설비의 배치도면
# 원재료 및 제품의 취급,제조등의 작업방법의 개요
#
# ⭐️건설공사 착공 유해위험방지계획서 제출기한: 해당공사의 착공전날 까지
# 첨부서류 3가지: 공사개요, 안전보건관리계획, [작업공사] 종류별 유해위험방지계획
#
# ⭐️신업안전보건위원회의 근로자위원 자격3가지
# 근로자 대표
# 근로자 대표가 지명하는 1명 이상의 명예산업안전감독관
# 근로자 대표가 지명하는 9명 이내의 해당사업장의 근로자
#
# ⭐️사업장의 안전 및 보건에 관한 중요 사항을 심의,의결하기 위하여 사업장에 근로자위원과 사용자위원이 같은 수로 구성되는 회의체-출석위원,개최일시및장소,심의내용및의결결정사항
# 회의체명: 산업안전보건위원회
# 해당회의주기: 분기(3개월)
# 근로자위원: 근로자 대표, 근로자 대표가 지명하는 1명 이상의 명예산업안전감독관, 근로자 대표가 지명하는 9명 이내의 해당사업장의 근로자
# 사용자위원: 해당사업장의 대표자, 산업보건의, 안전관리자, 보건관리자
#
# 2025 2회차 실기 필답 출제
# ⭐️방폭구조 기호
# 안전증: Ex e
# 충전 : Ex q
# 유입 : Ex o
# 특수 : Ex s
#
# ⭐️사망만인율= (사망자수/산재보험적용 근로자수)* 10^4
# 사망자수에 포함되지 않는 경우2가지: [폭력행위]에 의한 사망, [체육행사]에 의한 사망, [사업장밖의] 교통사고에의한 사망, [사고발생일로부터1년]을 경과하여 사망
#
# ⭐️특급방진마스크 사용장소
# 베릴륨등과 같이 [독성이강한] 물질들을 [함유한분진등] 발생장소
# 석면취급장소
#
# ⭐️시업주가 근로자에게 시행해야 하는 안전보건교육 중, 건설업 기초 안전,보건교육의 내용3가지
# 건설공사의 종류(건축,토목 등)및 시공 절차- [1시간]
# 산업재해 유형별 위험요인 및 안전보건조치- [2시간]
# 안전보건관리체제 현황 및 산업안전보건 관련 근로자권리,의무- [1시간]
#
#
# 2025 2회차 실기 필답 출제
# ⭐️⭐️용접작업을 하는 작업자가 전압이 300V인 충전부분이 물에 젖은 손이 접촉,감전되어 사망하였다.
# 인체에 통전된 심실세동전류[mA]와 통전시간[ms]
# sol) I = V/R = 300/(1000*1/25) = 7.5[A] * [10^3] = 7500[mA]
#      I = 165/루트T , 루트T = 165/7500[mA] , T = 0.000484[] * [10^-3] = 0.48[ms]
#
# ⭐️인체 계측자료를 장비나 설비의 설계에 응용하는 경우 활용되는 원칙3가지
# 극단치 (최대치수와 최소치수)
# 조절장치
# 평균치
#
# ⭐️손쳐내기식 방호장치를 사용하는 기계,기구
# 명칭 : 프레스, 전단기
# 분류기호 : D
#
# ⭐️양수:  B-1, B-2
# ⭐️수인식: E
#
# ⭐️안전밸브 형식표시사항
# S F II 1 - B
# S   :  [요구성능]
# F   :  [유량제한기구]
# II  :  [호칭지름구분]
# 1   :  [호칭압력구분]
# B   :  [평형형]
#
# 사업주가 작업중지명령 해제신청서를 제출하는 경우에는 미리 유해,위험요인 개선 내용에 대하여 중대재해가 발생한 해당작업 [근로자]의 의경을 들어야 한다.
# 지방고용노동관서의 장은 작업중지명령 해제를 요청받은 경우에는 [근로감독관]으로 하여금 안전,보건을 위하여 필요한 조치를 확인하도록 하고,
# 천재지변 등 불가피한 경우를 제외하고는 해제요청일 다음날부터[4일]이내(토요일과 공휴일을 포함하되, 토요일과 공휴일이 연속하는 경우에는 3일 까지만 포함)에
# [작업중지해제심의위원해]를 개최하여 심의한 후 해당조치가 완료되었다고 판단될 경우에는 즉시 작업중지 명령을 해제해야한다.
#
# 사업주는 사업장에 대통령령으로 정하는 유해하거나 위험한 설비가 있는 경우 "즁대산업사고"를 예방하기 위하여 [공정안전보고서]를 작성하고 고용노동부장관에게 재출하여 심사를 받아야 한다.
# 사업주는 제1항에 따라 [공정안전보고서]를 작성할 때 [산업안전보건위원회]의 심의를 거쳐야 한다.
# 다만, [산업안전보건위원회]가 설치되어 있지 아니한 사업장의 경우에는 근로자 대표의 의견을 들어야 한다.
#
#
# ⭐️보호구 안전인증 고시 상 명칭: 안전블록
# 갖추어야 할 구조 조건: [자동잠김장치], [부식방지처리]
#
# ⭐️'인체'에 대전된 정전기에 의한 화재 또는 폭발 위험이있는 경우 필요한 사업주의 조치사랑4가지
# 정전기 대전방지용 [안전화착용]
# [제전복착용]
# 정전기 [제전용구사용]
# [작업장바닥]등에 [도전성을] 갖추도록 함
#
# ⭐️중량물 취급 관리감독자 점검 사항2가지
# 중량물 취급의 [올바른자세및복장]
# 위험물이 날아 흩어짐에 따른 [보호구의착용]
# 카바이드,생석회 [등과같이] [온도상승]이나 [습기]에의하여 [위험성이존재]하는 [중량물의취급방법]
#
# ⭐️작업발판 일체형 거푸집 종류4가지
# 갱슬터클
# 갱폼
# 슬립폼
# 터널라이닝폼
# 클라이밍폼
#
# ⭐️마그네슘분말, 등유, 과염소산, 아세틸렌, 리튬
# 인화성가스: 아세틸렌
# 인화성액체: 등유
# 신화성 액체 및 산화성 고체: 과염소산
#
# ✅비상구 1개 이상을 설치해야 하는 구조조건
# 출입구와 같은 방향에 있지 아니하고, 출입구로붙터 [3m]이상 떨어져 있을 것
# 작업장의 각 부분으로 부터 하나의 비상구 또는 출입구 까지의 수평거리가 [50m]이하가 되도록 할 것
# 비상구의 너비는 [0.75m]이상으로 하고, 높이는 [1.5m]이상으로 할 것
#
# ✅콘크리트 타설작업시 사업주의 준수사항
# [거푸집붕괴]의 위험이 발생할 우려가 있는 경우 충분한 보강조치를 할 것
# 설계도면상의 콘크리트 [양생기간]을 준수하여 거푸집 및 동바리를 해체 할 것
# 편심이 발생하지 않도록 골고루 분산하여 타설할 것
#
# 음암수준= 100dB - 20log(200/20) = 80dB
#
# 광전자식 방호장치의 형식에 적합한 광축의 범위
# A  : 12광축 이하
# B  : 13~56광축 미만
# C  : 56광축 이상
#
# 🔥이동식크레인의 점검사항3가지-권브와
# 권과방지장치 및 그밖의 [경보장치]의 기능
# 브레이크, 클러치 및 [조정장치]의 기능
# 와이어로프가 통하고 있는 곳 및 [작업장소]의 [지반상태]
#
# 🔥이동식크레인의 방로장치4가지-권과제비
# 권과방지장치
# 과부하방지장치
# 제동장치
# 비상정지장치
#
# ⭐️Hazop 기법에 사용되는 가이드워드
# AS WELL AS : 성질상의 증가
# PART OF : 일부변경, 성질상의 감소
# OTHER THAN : 완전대체
# REVERSE : 설계의도의 논리적인 역
# NO 또는 NOT : 완전한부정
# More 또는 less : 양의 증가 및 감소
#
# LD50
# 1회투여로 실험동물의 50%를 사망케 하는 양
# LC50
# 1회투여로 실험동물의 50%를 사망케 하는 농도
#
# 🔥연삭숫돌 작업시작전 [1분]이상, 교체후 [3분]이상 시험운전을 하고
#
# 🌪️양립성
# 개념 양립성: 온수는 빨간색, 냉수는 파란색
# 공간 양립성: 오른쪽 버튼을 누르면 오른쪽 기계가 작동인다
# 운동 양립성: 자동차 핸들을 오른쪽으로 움직이면 회전바퀴가 오르쪽으로 회전
#
# 🌪️내화구조
# 건축물의 기둥 및 보 : 지상1층(지상1층의 높이가 6m를 초과하는 경우 6m)까지
# 위험물[저장,취급용기의]지지대(높이가30cm이하인 것은 제외): 지상층부터 지지대의 끝부분까지
# [배관,전선관등의]지지대 :지상으로부터 1단(1단의 높이가 6m를 초과하는 경우 6m)까지
#
# ⭐️사업주가 화재감시자를 지정하여 용접,용단 작업 장소에 배치하여야 하는 장소3곳
# 1. 작업반경[11m이내]에 건물구조 자체나 내부(개구부 등으로 개방된 부분을 포함)에
# 가연성 물질이 있는 장소
#
# 2. 작업반경 [11m이내]의 바닥 하부에
# 가연성물질이 [11m이상] 떨어져 있지만, 불꽃에 의해 쉽게 발화될 우려가 있는 장소
#
# 3. 가연성물질이 금속으로된 [칸막이,벽,천장,지붕]의
# 반대쪽 면에 인접해 있어, 열전도나 열복사에 의해 발화될 우려가 있는 장소
#
# ⭐️연삭기 덮개의 시험방법 중 연삭기 작동시험 확인사항
# 연산[숫돌]과 덮개의 접촉여부
# 탁상용 연삭기는 덮개,[워트레스트] 및 [조정편]부착상태의 적합성 여부
#
# ⭐️차량계 하역운반기계 등을 사용하는 작업의 작업계획서의 내용 2가지 -추낙전협붕
# 해당 작업에 따른 [추락/낙하/전도/협착/붕괴]등의 [위험예방대책]
# 차량계 하역운반기계등의 [운행경로] 및 [작업방법]
#
# ⭐️산업안전보건관리비
# 관급재료비 포함
# 1. (((25+3+10)*10^8)*0.0228)+4,325,000 = 90,965,000
# 관습재료비 불포함 *1.2
# 2. ((((25+10)*10^8)*0.0228)+4,325,000)*1.2 = 100,950,000
#
# 1.2.중에 더 작은 값(원)이상
# 따라서 산업안전보건관리비는 90,965,000원 이상이다.
#
# ⭐️하인리히 재해 구성비율
# 중상또는 사망1회
# 경상 29회
# 무상해 사고 300회
#
# 🔥충전전로선간전압[kV] 접근거리제한[cm]
# 0.3이하           접근제한
# 0.3              30
# 0.75             45
# 2                60
# 15               90
# 37               110
# 88               130
# 121              150
# 145              170
# 169              230
# 242              380
#
# ⭐️사다리식 통로의 길이가 [10m]이상인 경우에는 [5m]이내마다 계단참을 설치할 것
# 사다리식 통로의 기울기는 [75도]이하로 할 것.
# 다만, 고정삭 사다리식 통로의 기울기는 [90도]이하로 하고,
# 그 높이가 [7m]이상인 경우에는 바닥으로부터 높이가 [2.5m]되는 지점부터 등받이울을 설치할 것
#
# ⭐️와이어로프 사용금지사항 6가지
# 꼬인 것
# 이음매가 있는 것
# 삼하게 변형되거나 부식된 것
# 열 또는 전기충격에 의해 손상된 것
# 지름의 감소가 공칭지름의 7%를 초과한 것
# 와이어로프 한 꼬임에서 끊어진 소선의 수가 10%이상인 것
#
# ⭐️화물 운반용 또는 고정용으로는 사용할 수 없는 섬유로프의 조건2가지
# 꼬임이 끊어진 것
# 심하게 손상되거나 부식된 것
#
# ⭐️건축물,기계,기구 및 설비등 전부를 설치이전하거나 구조부분 변경하는 경우 [유해위험방지계획서]를 제출할때 첨부[서류]3가지
# 건축물 [각층의] [평면도]
# [기계,설비]의 [개요]를 나타내는 서류
# [기계설비]의 [배치도면]
#
#
# 🤮이동식비계 준수사항5가지-이승비작작
# 이동식비계의 [바퀴]에는 뜻밖의 갑작스러운 이동 또는 [전도]를 방지하기 위하여 브레이크,쐐기 등으로 바퀴를 고정시킨 다음,비계의 일부를 견고한 시설물에 고정하거나 [아웃트리거]를 설치하는 등 필요한 조치를 할 것.
# [승강용사다리]는 견고하게 설치할 것.
# 비계의 [최상부]에서 작업을 하는 경우에는 [안전난간]을 설치할 것
# 작업발판은 항상[수평]을 유지하고 작업발판 위에서, [안전난간]을 딛고 작업을 하거나, [받침대] 또는 [사다리]를 사용해서 작업하지 않도록 할 것.
# 작업발판의 최대적재하중은 [250kg]을 초과하지 않도록 할 것.
#
# 🤮노사협의체 설치 대상 사업장: 공사금액[120억원]이상의 [건설공사].([토목공사업]은 [150억원]이상)
# 정기회의 개최주기: [2개월]마다
#
# 🤮방진마스크의 종류에 맞는 형식
# [직결]식 반면형
# 격리식 반면형
# 직결식 전면형
#
# 🤮공정안전보고서 내용
# 공정안전자료
# 공정위험성 평가서-[PHR,ETA,FTA,HAZOP]
# 안전운전계획
# 비상조치계획
#
# [공정위험분석]: Procces Hazard Reviwe
# [사건수분석]: Event Tree Analysis
# [결함수분석]: Fault Tree Analysis
# [위험과운전분석]: Hazard & Operabilty
#
# 🤮🤮
# 1.채용시,작업내용변경시 교육-산산산직직위
# 2.근로자,관리감독자 정기교육-산산산직직위
# 3.특수채용시-산산산직직정작
# 4.안전보건관리규정-안안작사
# 5.안전보건관리책임자-산안근근
# 6.안전보건관리담당자-안위작건
# 7.안전보건총괄책임자-위도작산안
# 8.안전관리자-안위사업
# 9.관리감독자-해해근기
#
# 안위작건
# 안전보건교육 실시에 관한 보좌 및 조언지도
# 위험성평가에 관한 보좌 및 조언지도
# 작업환경 측정 및 [개선]에 관한 보좌 및 조언지도
# [건강진단]에 관한 보좌 및 조언지도
#
# 🤮대지전압[150V], 정격부하전류[30A], 정격감도전류[30mA이하],  [0.03초이내].
# 정격부하전류[50A이상], 정격감도전류[200mA이하], [0.1초이내]
